# %% [markdown]
# # Geomagnetic herbivore — reproducible pipeline
#
# Run from repo root or this directory:
#
# ```bash
# pip install -r requirements.txt
# python ../scripts/run_pipeline.py
# ```
#
# Outputs: `../data/anomaly_report.json`, `../output/fig_*.png`

# %%
import subprocess, sys
from pathlib import Path
root = Path('..').resolve()
r = subprocess.run([sys.executable, str(root / 'scripts' / 'run_pipeline.py')], cwd=root)
raise SystemExit(r.returncode)
